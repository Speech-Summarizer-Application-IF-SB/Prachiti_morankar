# %%
# !pip install librosa noisereduce soundfile ffmpeg-python

# %%
import whisper

model = whisper.load_model("base")
result = model.transcribe("my_audio.wav")
print("📜 Transcript:\n", result["text"])
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📜 Transcript:
#   The stale smell of old beer lingers. It takes heat to bring out the odor. A cold dip restores health and zest. A salt pickle tastes fine with ham. Tacos al pastor are my favorite. A zestful food is the hot cross bun.

# %%
from google.colab import files
uploaded = files.upload()

file_name = list(uploaded.keys())[0]
print("✅ Uploaded:", file_name)
# Out:
#      <input type="file" id="files-2af53c9a-7faa-404f-9415-633fd2a81630" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2af53c9a-7faa-404f-9415-633fd2a81630">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import soundfile as sf
import noisereduce as nr

def denoise_audio(input_file, output_file="cleaned.wav"):
    # Read audio file
    data, rate = sf.read(input_file)

    # Take first 0.5 seconds as noise sample
    noise_clip = data[:int(0.5 * rate)]

    # Reduce noise
    cleaned = nr.reduce_noise(y=data, sr=rate, y_noise=noise_clip)

    # Save cleaned audio
    sf.write(output_file, cleaned, rate)
    print(f"🎧 Cleaned audio saved as {output_file}")
    return output_file

out = denoise_audio(file_name, "denoised.wav")
# Out:
# 🎧 Cleaned audio saved as denoised.wav

# %%
# !pip install noisereduce

# %%
import soundfile as sf
import noisereduce as nr

def denoise_audio(input_file, output_file="cleaned.wav"):
    data, rate = sf.read(input_file)
    noise_clip = data[:int(0.5 * rate)]
    cleaned = nr.reduce_noise(y=data, sr=rate, y_noise=noise_clip)
    sf.write(output_file, cleaned, rate)
    print(f"✅ Cleaned audio saved: {output_file}")
    return output_file

# %%
# !pip install openai-whisper
import whisper

model = whisper.load_model("base")
result = model.transcribe("denoised.wav")
print("📜 Transcript:\n", result["text"])
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📜 Transcript:
#   So what have you been up to recently? Quite a lot actually. I've been away on business a couple of times and I'm going away again in the next few months. Oh really? Where to? Madrid's. I'll come to the US and open your office there. Cool. It's been a long time since I was in Madrid. But I'm sure you're liking it. Yeah, I'm looking forward to the trip. Anyway, how I've been to you. Do you still see Dave? Once in a while, not so much now he's moved away. What about you? No, actually we lost touch.
